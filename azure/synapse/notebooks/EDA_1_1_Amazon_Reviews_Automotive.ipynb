# %% [markdown]
# # Text processing and topic modelling of Amazon reviews
# * Automotive category analysis

# %% [markdown]
# ### Importing libs

# %%
import os
import re
from dotenv import load_dotenv
from pyspark.sql import SparkSession
from delta import *
import pyspark.sql.functions as F

from sparknlp.base import DocumentAssembler
from sparknlp.annotator import Tokenizer
from sparknlp.annotator import Lemmatizer
from sparknlp.annotator import LemmatizerModel
from sparknlp.annotator import Normalizer
from sparknlp.annotator import StopWordsCleaner
from sparknlp.base import Finisher
# Out:
# c:\Python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Python38\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# c:\Python38\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
load_dotenv()

STORAGE_ACCOUNT_NAME = os.getenv('STORAGE_ACCOUNT_NAME')
STORAGE_ACCOUNT_KEY = os.getenv('STORAGE_ACCOUNT_KEY')

builder = SparkSession.builder\
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-azure:3.3.4,\
io.delta:delta-core_2.12:2.4.0,\
io.delta:delta-storage:2.4.0,\
com.johnsnowlabs.nlp:spark-nlp_2.12:4.3.0")\
        .config(f"fs.azure.account.key.{STORAGE_ACCOUNT_NAME}.dfs.core.windows.net", f"{STORAGE_ACCOUNT_KEY}")\
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")\
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
root = 'abfss://default@stdatalakeakita.dfs.core.windows.net/synapse/workspaces/syn-synfactoreddatathon01-dev'

df = spark.read\
.format('delta')\
.load(f'{root}/silver/silver_amazon_reviews_automotive')

df.show()
# Out:
# +--------------+----------+--------------------+------+-------+--------------------+--------------------+--------------------+--------------------+--------------+-----------------+------------+------------+--------------------+------------+---------+-------------+
# |   reviewer_id|      asin|               title|  rank|overall|flg_positive_overall|flg_negative_overall|             summary|         review_text|         brand|     2nd_category|3rd_category|4th_category|            also_buy|also_buy_qty|also_view|also_view_qty|
# +--------------+----------+--------------------+------+-------+--------------------+--------------------+--------------------+--------------------+--------------+-----------------+------------+------------+--------------------+------------+---------+-------------+
# |A2TYWZQNOGX2YS|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Vent Shade|Did great for me....|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A26MXKD3CLMCIE|B0001EVUCM|Auto Ventshade 77...|364973|      3|                true|               false|Goo quality but n...|It's nice but be ...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A1J30QTX8ZIQG4|B0001EVUCM|Auto Ventshade 77...|364973|      3|                true|               false|Almost doesn't co...|Definitely doesn'...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# | ADIB9YLTI0CXG|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|... a 2014 F 150 ...|I have a 2014 F 1...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2F0WVU0Z8B4K8|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|Great product. Wo...|Reduces wind nois...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A32PMN8Y7TS9W4|B0001EVUCM|Auto Ventshade 77...|364973|      2|               false|                true|           Two Stars|it came off after...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A345GJXMWEX5FS|B0001EVUCM|Auto Ventshade 77...|364973|      1|               false|                true|it came totally b...|It came totally b...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A23IYKDMCQSDOX|B0001EVUCM|Auto Ventshade 77...|364973|      4|                true|               false|         wingflector|i like it alot. m...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2MNGI399IF2T9|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|... w the Sky Sli...|My wife has a 200...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# | AGGXG3ME3LGR1|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|Fits perfect on a...|I put the visor o...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# | AQ3JFQRSJM3B8|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|Easy to install a...|I drive a 2007 Mi...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2U82GKRJ3FL10|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Five Stars|great product, ex...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A21SAOI0WOC6ET|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Five Stars|               Great|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2PBMDGUZMMSHW|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Five Stars|           Fits good|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A30O8TVE1Y4UDF|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|       Great product|Works beautifully...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A1R9DLV31WRFXE|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Five Stars|           Great fit|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2DM65KSXB6M50|B0001EVUCM|Auto Ventshade 77...|364973|      5|                true|               false|          Five Stars|Easy Install.. Lo...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A1JMNT65CM5665|B0001EVUCM|Auto Ventshade 77...|364973|      1|               false|                true|Not good for Jeep...|It didn't fit the...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# |A2Y9GM6UMK42WU|B0001EVUCM|Auto Ventshade 77...|364973|      3|                true|               false|               works|it cut the noise ...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# | A3RJWICH3KHOT|B0001EVUCM|Auto Ventshade 77...|364973|      4|                true|               false|Product itself is...|Product itself is...|Auto Ventshade|Replacement Parts| Body & Trim|        Body|[B00HR0CAMW, B00C...|           3|       []|            1|
# +--------------+----------+--------------------+------+-------+--------------------+--------------------+--------------------+--------------------+--------------+-----------------+------------+------------+--------------------+------------+---------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Pre-processing review text

# %% [markdown]
# #### 1. Removing ponctuation

# %%
def clean_text(c):
  c = F.lower(c)
  c = F.regexp_replace(c, "(https?\://)\S+", "") # Remove links
  c = F.regexp_replace(c, "(\\n)|\n|\r|\t", "") # Remove CR, tab, and LR
  c = F.regexp_replace(c, "(?:(?:[0-9]{2}[:\/,]){2}[0-9]{2,4})", "") # Remove dates
  c = F.regexp_replace(c, "@([A-Za-z0-9_]+)", "") # Remove usernames
  c = F.regexp_replace(c, "[0-9]", "") # Remove numbers
  c = F.regexp_replace(c, "\{|\}|\[|\]|\(|\)|\;|\:|\/|\#|\.|\?|\!|\&|\"|\,", "") # Remove symbols
  c = F.regexp_replace(c, ' +', ' ')# Remove multiple whitespaces
  c = F.trim(c)# Remove trailing whitespaces
  return c

df = df.withColumn("review_text_process", clean_text(F.col("review_text")))

# %% [markdown]
# #### 2. Document Assembler

# %%
# Removing null texts
df_reviews_automotive = (
    df
    .withColumn('review_text_process', F.coalesce(F.col('review_text_process'), F.lit('Null Review')))                    
)

# Step 1: Transforms raw texts to `document` annotation
document_assembler = (
    DocumentAssembler()
    .setInputCol("review_text_process")
    .setOutputCol("document")
)

# %% [markdown]
# #### 3. Tokenizer

# %%
# Step 3: Tokenization
tokenizer = (
    Tokenizer()
    .setInputCols(["document"])
    .setOutputCol("token")

)

# %% [markdown]
# #### 4. Normalizer

# %%
normalizer= Normalizer()\
    .setInputCols(["token"])\
    .setOutputCol("normalized")\
    .setLowercase(True)

# %% [markdown]
# #### 5. Removing Stop Words

# %%
from nltk.corpus import stopwords
eng_stopwords = stopwords.words('english')

stopwordsCleaner =StopWordsCleaner()\
    .setInputCols(["normalized"])\
    .setOutputCol("no_stop_words")\
    .setStopWords(eng_stopwords)

# %% [markdown]
# #### 6. Lemmatizer

# %%
lemmatizer = LemmatizerModel.pretrained() \
.setInputCols(["no_stop_words"]) \
.setOutputCol("lemma")
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907,6 KB
# [OK!]

# %% [markdown]
# #### 7. POSTagger

# %%
from sparknlp.annotator import PerceptronModel
pos_tagger = PerceptronModel.pretrained('pos_anc') \
     .setInputCols(['document', 'lemma']) \
     .setOutputCol('pos')
# Out:
# pos_anc download started this may take some time.
# Approximate size to download 3,9 MB
# [OK!]

# %% [markdown]
# #### 8. Chunk

# %%
from sparknlp.annotator import Chunker
allowed_tags = ['<JJ>+<NN>', '<NN>+<NN>']
chunker = Chunker() \
     .setInputCols(['document', 'pos']) \
     .setOutputCol('ngrams') \
     .setRegexParsers(allowed_tags)

# %% [markdown]
# #### 9. Finisher

# %%
finisher = Finisher() \
.setInputCols(['lemma', 'ngrams'])

# %% [markdown]
# #### 10. Pipeline

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline() \
     .setStages([document_assembler,
                 tokenizer,
                 normalizer,
                 stopwordsCleaner,
                 lemmatizer,
                 pos_tagger,
                 chunker,
                 finisher])

df_reviews_automotive = pipeline.fit(df_reviews_automotive).transform(df_reviews_automotive)

# %%
df_reviews_automotive = df_reviews_automotive.withColumn('final',
     F.concat(F.col('finished_lemma'), 
            F.col('finished_ngrams')))

df_reviews_automotive.limit(10).show(truncate=False)
# Out:
# +--------------+----------+---------------------------------------------------------------------------+-----+-------+--------------------+--------------------+-------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+--------------------+------------+---------------+--------+------------+---------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |reviewer_id   |asin      |title                                                                      |rank |overall|flg_positive_overall|flg_negative_overall|summary                                                      |review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |brand           |2nd_category        |3rd_category|4th_category   |also_buy|also_buy_qty|also_view|also_view_qty|review_text_process                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# +--------------+----------+---------------------------------------------------------------------------+-----+-------+--------------------+--------------------+-------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+--------------------+------------+---------------+--------+------------+---------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...
# |AGRRGDPFDU53  |B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|1      |false               |true                |worked for 2 days SAE certified junk                         |4 hour install time worked great first night only to realize when i got in my car i had no power to my heater...\n\nchecked all wiring again to find i hooked accessory wire wire to ignition wire no problem fixed this and now it starts and i have heat. great.\n\nsecond night 4am rolls around i go to window to push button nothing i hit the stop button no lights flashing even go out to car dead battery\nand remote start box is clicking grab jump starter hook up let charge for 30 min start car via the key only to notice the remote start box is still clicking press brake pedal clicking stops.\n\nthinking this thing is going to show a huge fault / rip off when i go to run a draw test on the battery latter to day.\n\nwell check all connections all are solid still as i soldered them with silver solder ran draw test unit draws 1A and also no longer works\nreset the unit using the turn key 5 times as per instructed in manual hit start with key out of ignition and lights blink once nothing more.\n\ni would bet the bank on the unit fried it self as obvious 1 amp draw is way to much.  and when first installed was 43 milli amps or 0.043 amps\nnow 1 amp and when i disconnect unit it goes back to 0.039 guess i know where the problem is\n\nJunk from Junk company hate to half to write a bad review but i have herd stories while working in a parts store for a year about bulldog products i will be sure to help people steer clear of bulldog products as now i have found out first hand the root of the cause poor manufacturing.\n\nwill open circuit box later to day and up load photo i am sure i will find a few burnt chips and marks on the board along with terrible connections with small wires to support 1~5 amp draws that are normal of ignition wires let alone accessory wires running heaters with normal being 10~15 amp on high.                                                                                                                                                                                     |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |hour install time worked great first night only to realize when i got in my car i had no power to my heaterchecked all wiring again to find i hooked accessory wire wire to ignition wire no problem fixed this and now it starts and i have heat greatsecond night am rolls around i go to window to push button nothing i hit the stop button no lights flashing even go out to car dead batteryand remote start box is clicking grab jump starter hook up let charge for min start car via the key only to notice the remote start box is still clicking press brake pedal clicking stopsthinking this thing is going to show a huge fault rip off when i go to run a draw test on the battery latter to daywell check all connections all are solid still as i soldered them with silver solder ran draw test unit draws a and also no longer worksreset the unit using the turn key times as per instructed in manual hit start with key out of ignition and lights blink once nothing morei would bet the bank on the unit fried it self as obvious amp draw is way to much and when first installed was milli amps or ampsnow amp and when i disconnect unit it goes back to guess i know where the problem isjunk from junk company hate to half to write a bad review but i have herd stories while working in a parts store for a year about bulldog products i will be sure to help people steer clear of bulldog products as now i have found out first hand the root of the cause poor manufacturingwill open circuit box later to day and up load photo i am sure i will find a few burnt chips and marks on the board along with terrible connections with small wires to support ~ amp draws that  ...
# |A2QYDJT8DENK7V|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|4      |true                |false               |Washroom. trusteeship.                                       |Washroom.trusteeship.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |washroomtrusteeship                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# |A19LVNSDQDMGRW|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|5      |true                |false               |Excellent product, easy install, overall extremely satisfied.|This is just the product I wanted; just a remote start.  I have an older vehicle (1996 Jeep Cherokee Sport) without power windows or locks, so this suited my needs perfectly.  I live in a southern state with year round high humidity, and wanted the remote start to get the A/C going before I got to the car.  For $45, I was a little concerned I would be getting a cheaply made product, but I am satisfied by the quality completely; the transponder, wiring, module, and instructions were better than expected.\n\nINSTALL:\nI'm usually pretty hesitant to touch anything electrical in my car, but the wiring instructions were very clear.  Once I made the first connection, the rest came smoothly.  Even as a novice, the installation only took me about an hour, not including the time it too me to remove my dash to access the appropriate wiring.  All time including removing my lower dash, wiring, testing, installing the dash, and cleaning took me about 3 hours.  Again, I'm a "bolt-on" DIY type of person, but I usually leave this kind of thing to the professionals.  The instructions were VERY clear, and the vehicle wiring details provided by their website were excellent [...].  Also, the included probe worked as designed.  I appreciated the detailed instructions on how to connect a wire in line.\n\nOPERATION:\nThe start/stop function works exactly as described and responds to the transponder immediately.  The range also matched the advertised specs; my vehicle started beyond 400ft, although I didn't test it further.  I should also note I ran the antenna through some plastic molding to get it slightly above the dash.  The only failure I have for operation was the parking lights; I can hear the control module click as if it was signaling the parking lights, but they do not come on.  I may have to check that connection, so this is most likely my fault.\n\nOVERALL:\nI would buy this again in heartbeat.  Very satisfied with the price, the quality of the product, and the instructions.                  |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |this is just the product i wanted just a remote start i have an older vehicle jeep cherokee sport without power windows or locks so this suited my needs perfectly i live in a southern state with year round high humidity and wanted the remote start to get the ac going before i got to the car for $ i was a little concerned i would be getting a cheaply made product but i am satisfied by the quality completely the transponder wiring module and instructions were better than expectedinstalli'm usually pretty hesitant to touch anything electrical in my car but the wiring instructions were very clear once i made the first connection the rest came smoothly even as a novice the installation only took me about an hour not including the time it too me to remove my dash to access the appropriate wiring all time including removing my lower dash wiring testing installing the dash and cleaning took me about hours again i'm a bolt-on diy type of person but i usually leave this kind of thing to the professionals the instructions were very clear and the vehicle wiring details provided by their website were excellent also the included probe worked as designed i appreciated the detailed instructions on how to connect a wire in lineoperationthe startstop function works exactly as described and responds to the transponder immediately the range also matched the advertised specs my vehicle started beyond ft although i didn't test it further i should also note i ran the antenna through some plastic molding to get it slightly above the dash the only failure i have for operation was the parking lights i can hear the control module click as if it was  ...
# |A240Z280CDH02F|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|3      |true                |false               |Larry a..                                                    |excellent no problems so far had it for a few months I'm happy with it remote range isn't as far as I would like but I'm happy with it                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |excellent no problems so far had it for a few months i'm happy with it remote range isn't as far as i would like but i'm happy with it                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |A4HYQ9YG655T0 |B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|5      |true                |false               |Five Stars                                                   |awsome product easy to install, childsplay.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |awsome product easy to install childsplay                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |A39VDQUEM5CQY2|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|5      |true                |false               |Great Kit.                                                   |I bought this set two years ago.  This was my first installation and it was a breeze after I did my research on bulldog website and figured out all the wires that were needed to be used for my vehicle.  Bulldog website has everything you need.  It really does work and you should find out for yourself and don't let your local installers tell you otherwise.  When I asked my local installers to install this kit for me, they turned me away and told me bulldog is 99% faulty.  They sold me a Tarantula RS.2 kit for $139 and guaranteed it worked.  I bought the Tarantula RS.2 kit from the local installers and I decided to take my chances with the Bulldog kit (RS-82i) since it was only $30 when I bought it.  Installed both kit on two different vehicles.  After two months, the transmitter for the Tarantula RS.2 broke after I dropped my keys (they were the most fragile pieces of crap I've ever seen).  My bulldog remote starter never failed to start on extremely cold days that were sub-zero.  I can't say the same for the double-the-price kit I bought from the local installer.\nAnother note about BullDog.  Companies and Professional Installers can claim bulldog is junk.  But Bulldog has the best customer service you will find for DIY.  They provide wiring diagrams and color charts that no other companies will provide for you. If I have to install a remote starter from a different company I'd still have to get the wiring info from BullDog for my specific vehicle.\nTake a leap of faith and give the company a chance.  Most happens is it doesn't work and you return it, and gain a great learning experience about auto electronics if it works.  It's better than spend $200 - $300 for the locals to do it for you.  I've seen jobs done by professionals that ended up shorting out wires after a couple of years.  They bash on Bulldog because they want you to spend your money with them.  This is an honest review because Bulldog have earned it for the excellent two years of service the RS82i kit have given me.|Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |i bought this set two years ago this was my first installation and it was a breeze after i did my research on bulldog website and figured out all the wires that were needed to be used for my vehicle bulldog website has everything you need it really does work and you should find out for yourself and don't let your local installers tell you otherwise when i asked my local installers to install this kit for me they turned me away and told me bulldog is % faulty they sold me a tarantula rs kit for $ and guaranteed it worked i bought the tarantula rs kit from the local installers and i decided to take my chances with the bulldog kit rs-i since it was only $ when i bought it installed both kit on two different vehicles after two months the transmitter for the tarantula rs broke after i dropped my keys they were the most fragile pieces of crap i've ever seen my bulldog remote starter never failed to start on extremely cold days that were sub-zero i can't say the same for the double-the-price kit i bought from the local installeranother note about bulldog companies and professional installers can claim bulldog is junk but bulldog has the best customer service you will find for diy they provide wiring diagrams and color charts that no other companies will provide for you if i have to install a remote starter from a different company i'd still have to get the wiring info from bulldog for my specific vehicletake a leap of faith and give the company a chance most happens is it doesn't work and you return it and gain a great learning experience about auto electronics if it works it's better than spend $ - $ for the locals to do it for  ...
# |A128ZV710HUTQK|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|4      |true                |false               |Good product - lengthy install                               |I installed the bulldog remote starter RS82 on my sons 1993 Toyota Corolla. There was not a T-harness available so I had to install it the long way. The wiring schemes on bulldog's site were pretty accurate and very helpful. The video was ok but was very basic, I think they could spend more time on parts of it to make it more understandable for the newbie like me. It took about 7 hours to install it on this car, taking into consideration I only set it up with the starter and did not have to hook up a bypass or door locks it seemed to be a long drawn out process. I could do it faster now that I know what I'm doing though.\nA concern I had is that when you call the 'free' technical help line you do not really get any help so if you are taking on this project, just know you are on your own and will not get help. After it was all done I had accidently broken the hood pin switch so I sent Bulldog sales an email to order the part AND pay for it, I still have not gotten a reply so I tried calling and got another voicemail.\nSummary, the product works as it should (will find out if there are long term effects or not) and I'm happy with it thus far. NO tech support available which means work on this at your own risk level. I'm a pretty handy guy and will take on most anything, but going forward I will most likely hire to have this done - they earn every penny!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |i installed the bulldog remote starter rs on my sons toyota corolla there was not a t-harness available so i had to install it the long way the wiring schemes on bulldog's site were pretty accurate and very helpful the video was ok but was very basic i think they could spend more time on parts of it to make it more understandable for the newbie like me it took about hours to install it on this car taking into consideration i only set it up with the starter and did not have to hook up a bypass or door locks it seemed to be a long drawn out process i could do it faster now that i know what i'm doing thougha concern i had is that when you call the 'free' technical help line you do not really get any help so if you are taking on this project just know you are on your own and will not get help after it was all done i had accidently broken the hood pin switch so i sent bulldog sales an email to order the part and pay for it i still have not gotten a reply so i tried calling and got another voicemailsummary the product works as it should will find out if there are long term effects or not and i'm happy with it thus far no tech support available which means work on this at your own risk level i'm a pretty handy guy and will take on most anything but going forward i will most likely hire to have this done - they earn every penny                                                                                                                                                                                                                                                                                                                      ...
# |A1R48WTP2MG2R5|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|5      |true                |false               |easy remote start kit.                                       |The remote start installation was a breeze all I had to do is follow the instructions and the remote start worked perfect.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |the remote start installation was a breeze all i had to do is follow the instructions and the remote start worked perfect                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |A3IECTTPS4844S|B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|1      |false               |true                |Do not buy this item!                                        |Do not buy this item! I was told by bulldog it is an old model and Amazon should not be selling it. It came out of the box not working and now I have to pay to ship the unit back to bulldog for repair. It was pretty easy install but now I will have to wait a week or so to get a working replacement. I do not think it is fair that a product I purchased 4 days ago should be replaced by my refurbished original. The issue in a nutshell is that there is no range at all. I have to be within inches of the box or yellow standard antenna for it to work. I even went to the store to get a new battery for the key remote but it did not help. As for the people at bulldog the tech and the customer care rep were very nice, but there policies are subpar at best. I even feel bad writing this but it is true.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |do not buy this item i was told by bulldog it is an old model and amazon should not be selling it it came out of the box not working and now i have to pay to ship the unit back to bulldog for repair it was pretty easy install but now i will have to wait a week or so to get a working replacement i do not think it is fair that a product i purchased days ago should be replaced by my refurbished original the issue in a nutshell is that there is no range at all i have to be within inches of the box or yellow standard antenna for it to work i even went to the store to get a new battery for the key remote but it did not help as for the people at bulldog the tech and the customer care rep were very nice but there policies are subpar at best i even feel bad writing this but it is true                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# |AM6B0G3RG2SK8 |B00009WC2N|Bulldog RS82-I Do It Yourself Remote Starter - Automatic Transmissions only|19503|5      |true                |false               |LOVE THIS THING!!!!                                          |Install was easy enough. Price is unbeatable. Durability........well.....we'll have to wait and see. It should last forever since it has no real moving parts (other than electrical relays) but the plastic housing on the unit is hard and brittle not usually a sign of long lasting items. The fob is actually pretty nice though. It's got a slight rubberized texture to it. I bought one of these about a decade ago, same brand, this fob is definitely better than the last.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |Bulldog Security|Interior Accessories|Anti-Theft  |Remote Starters|[]      |1           |[]       |1            |install was easy enough price is unbeatable durabilitywellwe'll have to wait and see it should last forever since it has no real moving parts other than electrical relays but the plastic housing on the unit is hard and brittle not usually a sign of long lasting items the fob is actually pretty nice though it's got a slight rubberized texture to it i bought one of these about a decade ago same brand this fob is definitely better than the last                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# +--------------+----------+---------------------------------------------------------------------------+-----+-------+--------------------+--------------------+-------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+--------------------+------------+---------------+--------+------------+---------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ...

# %%
df_reviews_automotiveProcessed = (
    df_reviews_automotive
    .select('reviewer_id',
            'asin',
            'title',
            'rank',
            'overall',
            'flg_positive_overall',
            'flg_negative_overall',
            'summary',
            F.when(
                F.length(F.col('review_text_process')) > F.lit(4000), F.substring(F.col('review_text_process'), 1, 3999)
            )
            .otherwise(F.col('review_text_process')).alias('review_text'),
            F.col('finished_lemma'),
            F.col('final'),
            'brand',
            '2nd_category',
            '3rd_category',
            '4th_category')
)
df_reviews_automotiveProcessed.write.format('delta').save(f'{root}/gold/gold_amazon_reviews_automotive_text_processed')

# %% [markdown]
# #### 11. Count Vectorizer

# %%
from pyspark.ml.feature import CountVectorizer, CountVectorizerModel
#tfizer = CountVectorizer(inputCol='finished_lemma',
#                         outputCol='tf_features')
#tf_model = tfizer.fit(df_reviews_automotive)
tf_model = CountVectorizerModel.load('models/vectorizer/count-vectorizer-model')
df_reviews_automotive_tf = tf_model.transform(df_reviews_automotive)

# %% [markdown]
# #### 12. IDF

# %%
from pyspark.ml.feature import IDF, IDFModel
#idfizer = IDF(inputCol='tf_features', 
#              outputCol='tf_idf_features')
#idf_model = idfizer.fit(df_reviews_automotive_tf)
idf_model = IDFModel.load('models/idf/idf-model')
df_reviews_automotive_tfidf = idf_model.transform(df_reviews_automotive_tf)

# %% [markdown]
# #### 13. LDA

# %%
from pyspark.ml.clustering import LDA
lda = LDA(k=4, seed=1, optimizer="online", featuresCol='tf_idf_features')
lda.setMaxIter(50)
lda.clear(lda.maxIter)
model = lda.fit(df_reviews_automotive_tfidf)
model.setSeed(1)

# %% [markdown]
# #### 14. Save Model

# %%
lda_path = 'models/lda' + "/lda_k4"
lda.save(lda_path)
lda_model_path = 'models/lda' + "/lda_model_20230108_k4"
model.save(lda_model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 lda_path = 'models/lda' + "/lda_k4"
# ----> 2 lda.save(lda_path)
#       3 lda_model_path = 'models/lda' + "/lda_model_20230108_k4"
#       4 model.save(lda_model_path)
#
# NameError: name 'lda' is not defined

# %% [markdown]
# #### 15. Load Model

# %%
from pyspark.ml.clustering import LocalLDAModel

modelLoaded = LocalLDAModel.load('models/lda/lda_model_20230108_k4')
df_reviews_automotiveModel = modelLoaded.transform(df_reviews_automotive_tfidf)

# %% [markdown]
# #### 16. Show principal words

# %%
import pyspark.sql.types as T

vocab = tf_model.vocabulary

num_top_words = 15
topics = (modelLoaded
     .describeTopics(num_top_words)
     .withColumn('vocabulary', F.lit(vocab))
     .withColumn('topicWords', F.transform(F.col('termIndices'), lambda x: F.element_at(F.col('vocabulary'), x+1))))
topics.select('topic', 'topicWords').show(truncate=False)
# Out:
# +-----+--------------------------------------------------------------------------------------------------+
# |topic|topicWords                                                                                        |
# +-----+--------------------------------------------------------------------------------------------------+
# |0    |[great, work, good, install, product, fit, easy, part, price, well, look, quality, one, use, need]|
# |1    |[use, battery, get, work, one, car, time, love, buy, plug, charge, well, year, power, good]       |
# |2    |[light, fit, perfect, bright, well, look, bulb, great, buy, use, cover, like, get, make, one]     |
# |3    |[filter, get, fit, look, one, nice, key, car, make, seat, cover, like, back, use, well]           |
# +-----+--------------------------------------------------------------------------------------------------+

# %% [markdown]
# #### 17. Save vectorizer

# %%
countVectorizerPath = 'models/vectorizer' + "/count-vectorizer"
tfizer.save(countVectorizerPath)
modelPath = 'models/vectorizer' + "/count-vectorizer-model"
tf_model.save(modelPath)
idfPath = 'models/idf' + "/idf"
idfizer.save(idfPath)
modelPath = 'models/idf' + "/idf-model"
idf_model.save(modelPath)

# %% [markdown]
# #### 18. Write to ADLS GEN 2

# %%
from pyspark.ml.functions import vector_to_array


df_reviews_automotiveModel = (
    df_reviews_automotiveModel
    .withColumn('topicDistribution', vector_to_array(F.col('topicDistribution')))
    .withColumn('topic', F.expr('array_position(topicDistribution, array_max(topicDistribution))'))
    .select('reviewer_id',
            'topic',
            'asin',
            'title',
            'rank',
            'overall',
            'flg_positive_overall',
            'flg_negative_overall',
            'summary',
            F.when(
                F.length(F.col('review_text_process')) > F.lit(4000), F.substring(F.col('review_text_process'), 1, 3999)
            )
            .otherwise(F.col('review_text_process')).alias('review_text'),
            F.col('finished_lemma'),
            F.col('final'),
            'brand',
            '2nd_category',
            '3rd_category',
            '4th_category',
            F.col('topicDistribution').getItem(0).alias('Topic_1'),
            F.col('topicDistribution').getItem(1).alias('Topic_2'),
            F.col('topicDistribution').getItem(2).alias('Topic_3'),
            F.col('topicDistribution').getItem(3).alias('Topic_4'))
)
df_reviews_automotiveModel.write.format('delta').save(f'{root}/gold/gold_amazon_reviews_ctg_automotive')

# %%
import pyLDAvis
import numpy as np
pyLDAvis.enable_notebook()
df_reviews_automotiveModel = modelLoaded.transform(df_reviews_automotive_tfidf)
xxx = df_reviews_automotiveModel.select((F.explode(df_reviews_automotiveModel.final)).alias("words")).groupby("words").count()
word_counts = {r['words']:r['count'] for r in xxx.collect()}
word_counts = [word_counts[w] for w in tf_model.vocabulary]
vis = pyLDAvis.prepare(vocab = tf_model.vocabulary, 
                       topic_term_dists= np.array([row for row in modelLoaded.describeTopics(maxTermsPerTopic=len(tf_model.vocabulary)).select(F.col('termWeights')).toPandas()['termWeights']]),
                       doc_topic_dists=np.array([x.toArray() for x in df_reviews_automotiveModel.select(["topicDistribution"]).toPandas()['topicDistribution']]),
                       doc_lengths= [r[0] for r in df_reviews_automotiveModel.select(F.size(df_reviews_automotiveModel.finished_lemma)).collect()],
                       term_frequency=word_counts
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[27], line 8
#       6 word_counts = {r['words']:r['count'] for r in xxx.collect()}
#       7 word_counts = [word_counts[w] for w in tf_model.vocabulary]
# ----> 8 vis = pyLDAvis.prepare(vocab = tf_model.vocabulary,
#       9                        topic_term_dists= np.array([row for row in modelLoaded.describeTopics(maxTermsPerTopic=len(tf_model.vocabulary)).select(F.col('termWeights')).toPandas()['termWeights']]),
#      10                        doc_topic_dists=np.array([x.toArray() for x in df_reviews_automotiveModel.select(["topicDistribution"]).toPandas()['topicDistribution']]),
#      11                        doc_lengths= [r[0] for r in df_reviews_automotiveModel.select(F.size(df_reviews_automotiveModel.finished_lemma)).collect()],
#      12                        term_frequency=word_counts
#      13 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pyLDAvis\_prepare.py:411, in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     409 doc_lengths = _series_with_name(doc_lengths, 'doc_length')
#     410 vocab = _series_with_name(vocab, 'vocab')
# --> 411 _input_validate(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency)
#     412 R = min(R, len(vocab))
#     414 topic_freq = doc_topic_dists.mul(doc_lengths, axis="index").sum()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pyLDAvis\_prepare.py:69, in _input_validate(*args)
#      67 res = _input_check(*args)
#      68 if res:
# ---> 69     raise ValidationError('\n' + '\n'.join([' * ' + s for s in res]))
#
# ValidationError:
#  * Not all rows (distributions) in doc_topic_dists sum to 1.

# %%
df_reviews_automotiveModel.select('finished_lemma', 'topicDistribution').where(F.size(vector_to_array(F.col('topicDistribution'))) == F.lit(0)).show()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "c:\Python38\lib\site-packages\py4j\java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "c:\Python38\lib\site-packages\py4j\clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "c:\Python38\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_reviews_automotiveModel.select('finished_lemma', 'topicDistribution').where(F.size(vector_to_array(F.col('topicDistribution'))) == F.lit(0)).show()
#
# File c:\Python38\lib\site-packages\pyspark\sql\dataframe.py:899, in DataFrame.show(self, n, truncate, vertical)
#     893     raise PySparkTypeError(
#     894         error_class="NOT_BOOL",
#     895         message_parameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     896     )
#     898 if isinstance(truncate, bool) and truncate:
# --> 899     print(self._jdf.showString(n, 20, vertical))
#     900 else:
#     901     try:
#
# File c:\Python38\lib\site-packages\py4j\java_gateway.py:1320, in JavaMember.__call__(self, *args)
#    1313 args_command, temp_args = self._build_args(*args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
# -> 1320 answer = self.gateway_client.send_command(command)
#    1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#
# File c:\Python38\lib\site-packages\py4j\java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File c:\Python38\lib\site-packages\py4j\clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File c:\Python38\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:
